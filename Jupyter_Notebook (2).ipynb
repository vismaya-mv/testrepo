# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # MY JUPYTER NOTEBOOK ON IBM WATSON STUDIO

# %% [markdown]
# **NAME: VISMAYA M V**
#
# I AM CURRENTLY DOING MY MASTER'S DEGREE

# %% [markdown]
# *I am interested in Data science because as a mathematics students, I am interested more in problem solving fields which may lead my future career in data science*

# %% [markdown]
# ### TO FIND THE SUM OF TWO NUMBERS

# %%
a=int(input('Enter a number: '))
b=int(input('Enter a number: '))
sum=a+b
print('sum is',sum)
# Out:
# Enter a number:  1
# Enter a number:  2
# sum is 3

# %% [markdown]
# ***

# %% [markdown]
# - list1
# - list2
# - list3

# %% [markdown]
# 1. list4
# 1. list5
# 1. list6

# %% [markdown]
# ![data-science.jpg](attachment:eee0ca12-6f7e-4c75-aaf7-7ddb2276a83f.jpg)

# %% [markdown]
# ~~strikethrough~~
